# %%
import pandas as pd
import numpy as np
import streamlit as st
import os

# %%
current_directory = os.getcwd()

#Construct a relative path 

relative_path = os.path.join(current_directory, 'data', 'Poly 2023 LAS Reference.xlsx')



df =dict()
sheet_names = pd.ExcelFile(relative_path).sheet_names

for sheet in sheet_names:
    df[sheet]=pd.read_excel(relative_path,sheet_name=sheet)
    df[sheet]['Poly'] = sheet

df= pd.concat(df, ignore_index=True)

# %%
df.columns = df.columns.str.strip()

# %%
df['Poly-Course']= df['Course Name']+" "+"("+ df['MOE Course Code']+")"

df
# Out:
#     MOE Course Code                     Course Name Aggregate Type
# 0               R40           AEROSPACE ENGINEERING       ELR2B2-C  \
# 1               R17               APPLIED CHEMISTRY       ELR2B2-C
# 2               R25       ARTS & THEATRE MANAGEMENT       ELR2B2-A
# 3               R39             AVIATION MANAGEMENT       ELR2B2-C
# 4               R14              BIOMEDICAL SCIENCE       ELR2B2-C
# ..              ...                             ...            ...
# 197             T25          PHARMACEUTICAL SCIENCE       ELR2B2-C
# 198             T35    PRODUCT EXPERIENCE & DESIGN        ELR2B2-D
# 199             T48              PSYCHOLOGY STUDIES       ELR2B2-A
# 200             T53  SOCIAL SCIENCES IN GERONTOLOGY       ELR2B2-A
# 201             T45           VETERINARY TECHNOLOGY       ELR2B2-C
#
#     2023 Range of Aggregate Score (Net) Poly
# 0                                 12-26   RP  \
# 1                                 12-18   RP
# 2                                 13-19   RP
# 3                                 15-25   RP
# 4                                  7-12   RP
# ..                                  ...  ...
# 197                                5-10   TP
# 198                                5-16   TP
# 199                                 3-8   TP
# 200                                9-14   TP
# 201                                 5-9   TP
#
#                               Poly-Course
# 0             AEROSPACE ENGINEERING (R40)
# 1                 APPLIED CHEMISTRY (R17)
# 2         ARTS & THEATRE MANAGEMENT (R25)
# 3               AVIATION MANAGEMENT (R39)
# 4                BIOMEDICAL SCIENCE (R14)
# ..                                    ...
# 197          PHARMACEUTICAL SCIENCE (T25)
# 198    PRODUCT EXPERIENCE & DESIGN  (T35)
# 199              PSYCHOLOGY STUDIES (T48)
# 200  SOCIAL SCIENCES IN GERONTOLOGY (T53)
# 201           VETERINARY TECHNOLOGY (T45)
#
# [202 rows x 6 columns]

# %%
df['Poly-Course']= df['Course Name']+" "+"("+ df['MOE Course Code']+")"

df.sort_values(by='Poly-Course',inplace=True)

df
# Out:
#     MOE Course Code                                        Course Name
# 43              C98                              ACCOUNTANCY & FINANCE  \
# 161             T02                              ACCOUNTANCY & FINANCE
# 118             N51                                        ACCOUNTANCY
# 83              S75                                        ACCOUNTANCY
# 44              C62                   ADVANCED & DIGITAL MANUFACTURING
# ..              ...                                                ...
# 201             T45                              VETERINARY TECHNOLOGY
# 116             NaN                                                NaN
# 117             NaN  * previously known as INFOCOMM SECURITY MANAGE...
# 159             NaN                                                NaN
# 160             NaN  * previously known as AUTOMATION & MECHATRONIC...
#
#     Aggregate Type 2023 Range of Aggregate Score (Net) Poly
# 43        ELR2B2-B                                6-12  NYP  \
# 161       ELR2B2-B                                5-11   TP
# 118       ELR2B2-B                                4-12   NP
# 83        ELR2B2-B                                4-12   SP
# 44        ELR2B2-C                               15-23  NYP
# ..             ...                                 ...  ...
# 201       ELR2B2-C                                 5-9   TP
# 116            NaN                                 NaN   SP
# 117            NaN                                 NaN   SP
# 159            NaN                                 NaN   NP
# 160            NaN                                 NaN   NP
#
#                                 Poly-Course
# 43              ACCOUNTANCY & FINANCE (C98)
# 161             ACCOUNTANCY & FINANCE (T02)
# 118                       ACCOUNTANCY (N51)
# 83                        ACCOUNTANCY (S75)
# 44   ADVANCED & DIGITAL MANUFACTURING (C62)
# ..                                      ...
# 201             VETERINARY TECHNOLOGY (T45)
# 116                                     NaN
# 117                                     NaN
# 159                                     NaN
# 160                                     NaN
#
# [202 rows x 6 columns]

# %%
df.to_pickle('data.pickle')

# %%
df = pd.read_pickle('data.pickle')
df
# Out:
#     MOE Course Code                                        Course Name
# 43              C98                              ACCOUNTANCY & FINANCE  \
# 161             T02                              ACCOUNTANCY & FINANCE
# 118             N51                                        ACCOUNTANCY
# 83              S75                                        ACCOUNTANCY
# 44              C62                   ADVANCED & DIGITAL MANUFACTURING
# ..              ...                                                ...
# 201             T45                              VETERINARY TECHNOLOGY
# 116             NaN                                                NaN
# 117             NaN  * previously known as INFOCOMM SECURITY MANAGE...
# 159             NaN                                                NaN
# 160             NaN  * previously known as AUTOMATION & MECHATRONIC...
#
#     Aggregate Type 2023 Range of Aggregate Score (Net) Poly
# 43        ELR2B2-B                                6-12  NYP  \
# 161       ELR2B2-B                                5-11   TP
# 118       ELR2B2-B                                4-12   NP
# 83        ELR2B2-B                                4-12   SP
# 44        ELR2B2-C                               15-23  NYP
# ..             ...                                 ...  ...
# 201       ELR2B2-C                                 5-9   TP
# 116            NaN                                 NaN   SP
# 117            NaN                                 NaN   SP
# 159            NaN                                 NaN   NP
# 160            NaN                                 NaN   NP
#
#                                 Poly-Course
# 43              ACCOUNTANCY & FINANCE (C98)
# 161             ACCOUNTANCY & FINANCE (T02)
# 118                       ACCOUNTANCY (N51)
# 83                        ACCOUNTANCY (S75)
# 44   ADVANCED & DIGITAL MANUFACTURING (C62)
# ..                                      ...
# 201             VETERINARY TECHNOLOGY (T45)
# 116                                     NaN
# 117                                     NaN
# 159                                     NaN
# 160                                     NaN
#
# [202 rows x 6 columns]

# %%
# Sample DataFrame

# Streamlit App
st.title('2024 Poly Course Comparison')

# Multiselect to choose multiple items
selected_items = st.multiselect('Choose Course:', df['Poly-Course'])

# Button to trigger result display
result_button = st.button('Result')

# Display the selected items from the DataFrame
if result_button:
    selected_rows = df[df['Poly-Course'].isin(selected_items)]
    st.write('### Selected Items Details:')
    for index, row in selected_rows.iterrows():
        st.write(f"**Course:** {row['Poly-Course']}, **Range of Aggregate Score:** {row['2023 Range of Aggregate Score (Net)']}")
        
else:
    st.warning('Please select at least one item.')
# Out:
# 2023-12-16 17:57:30.273
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\chooyen\myenv\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]

# %%
df.sort_values(by=df['Poly-Course'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19452\1906578263.py in ?()
# ----> 1 df.sort_values(by=df['Poly-Course'])
#
# ~\myenv\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6764         elif len(by):
#    6765             # len(by) == 1
#    6766
#    6767             by = by[0]
# -> 6768             k = self._get_label_or_level_values(by, axis=axis)
#    6769
#    6770             # need to rewrap column in Series to apply key function
#    6771             if key is not None:
#
# ~\myenv\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1774             values = self.xs(key, axis=other_axes[0])._values
#    1775         elif self._is_level_reference(key, axis=axis):
#    1776             values = self.axes[axis].get_level_values(key)._values
#    1777         else:
# -> 1778             raise KeyError(key)
#    1779
#    1780         # Check for duplicates
#    1781         if values.ndim > 1:
#
# KeyError: 0               AEROSPACE ENGINEERING (R40)
# 1                   APPLIED CHEMISTRY (R17)
# 2           ARTS & THEATRE MANAGEMENT (R25)
# 3                 AVIATION MANAGEMENT (R39)
# 4                  BIOMEDICAL SCIENCE (R14)
#                        ...
# 197            PHARMACEUTICAL SCIENCE (T25)
# 198      PRODUCT EXPERIENCE & DESIGN  (T35)
# 199                PSYCHOLOGY STUDIES (T48)
# 200    SOCIAL SCIENCES IN GERONTOLOGY (T53)
# 201             VETERINARY TECHNOLOGY (T45)
# Name: Poly-Course, Length: 202, dtype: object
